# %%
from char_extraction import plot_list, get_adaptive_line_contours, get_lines, get_adaptive_words
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
# image preview
img= cv2.imread('C:\\Users\\smmal\\OneDrive\\Documents\\school\\2022-2023\\spring\\COS429\\ground_truths\\emma\\emma_005.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')
plt.show()

# %%
_, thresh, dilate, image_with_boxes, contours = get_adaptive_line_contours(img)
if contours is None:
    print("CONTOUR SEARCH FAILED")
# Out:
# 3
# 5
# 7

# %%
# preview intermediate images
plt.figure(figsize=(20,10))
plt.imshow(dilate, cmap='gray') # or thresh or dilate
plt.show()

# %%
lines = get_lines(img, contours)

# %%
# single line preview
plt.imshow(lines[3])
plt.show()

# %%
words = get_adaptive_words(lines)

# %%
# word preview
plot_list(words[20:40])
